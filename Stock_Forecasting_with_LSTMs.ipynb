# %% [markdown]
# Microsoft Stock Forecasting with LSTMs

# %%
import pandas as pd

df = pd.read_csv('/content/MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061434
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063628
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064725
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063079
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061982
# ...          ...         ...         ...         ...         ...         ...
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  300.429993
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  299.160004
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  304.059998
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  299.489990
# 9082  2022-03-24  299.140015  304.200012  298.320007  304.100006  304.100006
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9078    43317000
# 9079    28351200
# 9080    27599700
# 9081    25715400
# 9082    24446900
#
# [9083 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9078    2022-03-18
# 9079    2022-03-21
# 9080    2022-03-22
# 9081    2022-03-23
# 9082    2022-03-24
# Name: Date, Length: 9083, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /tmp/ipython-input-2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9078   2022-03-18
# 9079   2022-03-21
# 9080   2022-03-22
# 9081   2022-03-23
# 9082   2022-03-24
# Name: Date, Length: 9083, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-03-18  300.429993
# 2022-03-21  299.160004
# 2022-03-22  304.059998
# 2022-03-23  299.489990
# 2022-03-24  304.100006
#
# [9083 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 84706.0859 - mean_absolute_error: 289.3665 - val_loss: 92149.9609 - val_mean_absolute_error: 303.4749
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 83697.7734 - mean_absolute_error: 287.5886 - val_loss: 91851.3828 - val_mean_absolute_error: 302.9825
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 84002.8359 - mean_absolute_error: 288.1921 - val_loss: 91342.2812 - val_mean_absolute_error: 302.1411
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 82757.3359 - mean_absolute_error: 286.0698 - val_loss: 90406.8125 - val_mean_absolute_error: 300.5892
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 83880.9219 - mean_absolute_error: 287.8486 - val_loss: 89467.8438 - val_mean_absolute_error: 299.0232
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 80047.3750 - mean_absolute_error: 281.1650 - val_loss: 88433.7891 - val_mean_absolute_error: 297.2891
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 81572.5000 - mean_absolute_error: 283.8800 - val_loss: 87024.0078 - val_mean_absolute_error: 294.9084
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 79136.1875 - mean_absolute_error: 279.6467 - val_loss: 85025.1719 - val_mean_absolute_error: 291.4998
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 77581.3984 - mean_absolute_error: 276.7091 - val_loss: 82790.0625 - val_mean_absolute_error: 287.6405
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 75378.4844 - mean_absolute_error: 272.7233 - val_loss: 80300.9922 - val_mean_absolute_error: 283.2806
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 71618.2422 - mean_absolute_error: 265.7547 - val_loss: 77192.5469 - val_mean_absolute_error: 277.7401
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 69435.7344 - mean_absolute_error: 261.6835 - val_loss: 73682.5859 - val_mean_absolute_error: 271.3474
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 66344.2812 - mean_absolute_error: 255.6826 - val_loss: 69021.6484 - val_mean_absolute_error: 262.6183
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 62353.0312 - mean_absolute_error: 247.6691 - val_loss: 63692.6953 - val_mean_absolute_error: 252.2692
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 57343.2734 - mean_absolute_error: 237.2193 - val_loss: 58408.3242 - val_mean_absolute_error: 241.5682
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 51818.9336 - mean_absolute_error: 225.3723 - val_loss: 52569.2656 - val_mean_absolute_error: 229.1643
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 45023.6328 - mean_absolute_error: 209.6405 - val_loss: 46453.8398 - val_mean_absolute_error: 215.4083
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 41073.1523 - mean_absolute_error: 200.0302 - val_loss: 39706.7773 - val_mean_absolute_error: 199.1325
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 34413.4258 - mean_absolute_error: 182.7316 - val_loss: 33422.8359 - val_mean_absolute_error: 182.6742
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 27288.3398 - mean_absolute_error: 162.1872 - val_loss: 27302.5254 - val_mean_absolute_error: 165.0744
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22735.0605 - mean_absolute_error: 147.1097 - val_loss: 21500.5703 - val_mean_absolute_error: 146.4500
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 17514.4707 - mean_absolute_error: 128.3825 - val_loss: 16234.4600 - val_mean_absolute_error: 127.2065
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12989.7383 - mean_absolute_error: 109.2211 - val_loss: 11641.9141 - val_mean_absolute_error: 107.6513
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8863.7734 - mean_absolute_error: 88.5978 - val_loss: 7400.1704 - val_mean_absolute_error: 85.7154
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5899.7300 - mean_absolute_error: 69.5120 - val_loss: 4436.2412 - val_mean_absolute_error: 66.2064
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3067.3682 - mean_absolute_error: 46.2477 - val_loss: 2540.5947 - val_mean_absolute_error: 49.8762
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2064.6379 - mean_absolute_error: 36.1960 - val_loss: 1384.0632 - val_mean_absolute_error: 36.4842
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1207.0281 - mean_absolute_error: 28.7539 - val_loss: 737.2416 - val_mean_absolute_error: 26.1587
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1063.6063 - mean_absolute_error: 27.6302 - val_loss: 388.8853 - val_mean_absolute_error: 18.3282
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1085.3354 - mean_absolute_error: 27.8998 - val_loss: 235.7700 - val_mean_absolute_error: 13.6967
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1064.9456 - mean_absolute_error: 27.9528 - val_loss: 193.5109 - val_mean_absolute_error: 12.1647
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1063.6143 - mean_absolute_error: 27.9161 - val_loss: 184.9948 - val_mean_absolute_error: 11.8291
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1036.5070 - mean_absolute_error: 27.3649 - val_loss: 204.0925 - val_mean_absolute_error: 12.5678
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1016.8513 - mean_absolute_error: 27.3119 - val_loss: 219.4045 - val_mean_absolute_error: 13.1269
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1035.3293 - mean_absolute_error: 27.2703 - val_loss: 223.1287 - val_mean_absolute_error: 13.2590
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1034.3763 - mean_absolute_error: 27.1500 - val_loss: 238.2610 - val_mean_absolute_error: 13.7820
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 994.3669 - mean_absolute_error: 26.7818 - val_loss: 296.4595 - val_mean_absolute_error: 15.6181
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1001.5817 - mean_absolute_error: 26.4215 - val_loss: 296.4096 - val_mean_absolute_error: 15.6202
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1045.7025 - mean_absolute_error: 27.7055 - val_loss: 301.5539 - val_mean_absolute_error: 15.7824
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 978.4021 - mean_absolute_error: 26.6828 - val_loss: 291.0455 - val_mean_absolute_error: 15.4622
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 953.0229 - mean_absolute_error: 25.9782 - val_loss: 296.8834 - val_mean_absolute_error: 15.6383
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1018.0797 - mean_absolute_error: 27.0278 - val_loss: 287.2121 - val_mean_absolute_error: 15.3520
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1033.5322 - mean_absolute_error: 27.6175 - val_loss: 276.7990 - val_mean_absolute_error: 15.0380
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1060.7867 - mean_absolute_error: 28.0080 - val_loss: 308.8700 - val_mean_absolute_error: 16.0259
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1026.1124 - mean_absolute_error: 27.5347 - val_loss: 276.3613 - val_mean_absolute_error: 15.0279
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 969.3792 - mean_absolute_error: 26.4943 - val_loss: 313.9639 - val_mean_absolute_error: 16.2049
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1008.2137 - mean_absolute_error: 27.1465 - val_loss: 371.4241 - val_mean_absolute_error: 17.9157
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 975.2893 - mean_absolute_error: 26.8201 - val_loss: 266.1074 - val_mean_absolute_error: 14.7361
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 967.0339 - mean_absolute_error: 26.1013 - val_loss: 408.6735 - val_mean_absolute_error: 18.9642
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 857.5147 - mean_absolute_error: 24.5974 - val_loss: 257.5589 - val_mean_absolute_error: 14.4879
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 893.6996 - mean_absolute_error: 25.0350 - val_loss: 335.6117 - val_mean_absolute_error: 16.9485
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 918.5831 - mean_absolute_error: 25.8113 - val_loss: 298.0332 - val_mean_absolute_error: 15.8602
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 783.5620 - mean_absolute_error: 23.6743 - val_loss: 260.0180 - val_mean_absolute_error: 14.6401
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 718.1945 - mean_absolute_error: 22.6284 - val_loss: 189.0673 - val_mean_absolute_error: 12.1934
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 681.4994 - mean_absolute_error: 21.8554 - val_loss: 420.0024 - val_mean_absolute_error: 19.3978
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 790.1639 - mean_absolute_error: 23.5121 - val_loss: 150.8520 - val_mean_absolute_error: 10.6754
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 663.0431 - mean_absolute_error: 21.6014 - val_loss: 155.7843 - val_mean_absolute_error: 10.8896
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 594.0303 - mean_absolute_error: 20.3516 - val_loss: 142.4748 - val_mean_absolute_error: 10.4024
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 489.8248 - mean_absolute_error: 18.4928 - val_loss: 69.6405 - val_mean_absolute_error: 6.7488
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 449.0736 - mean_absolute_error: 17.7711 - val_loss: 114.4220 - val_mean_absolute_error: 9.1326
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 441.6498 - mean_absolute_error: 17.4836 - val_loss: 88.7411 - val_mean_absolute_error: 7.8275
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 361.0357 - mean_absolute_error: 15.5561 - val_loss: 141.8631 - val_mean_absolute_error: 10.4914
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 321.2130 - mean_absolute_error: 14.7785 - val_loss: 50.6874 - val_mean_absolute_error: 5.6838
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 316.9384 - mean_absolute_error: 14.7033 - val_loss: 37.1822 - val_mean_absolute_error: 5.2466
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 370.4241 - mean_absolute_error: 16.3701 - val_loss: 44.9709 - val_mean_absolute_error: 5.3941
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 292.8127 - mean_absolute_error: 14.4677 - val_loss: 55.1442 - val_mean_absolute_error: 5.9955
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 236.5957 - mean_absolute_error: 12.6417 - val_loss: 187.7863 - val_mean_absolute_error: 12.5122
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 222.7006 - mean_absolute_error: 12.1950 - val_loss: 208.0584 - val_mean_absolute_error: 13.3107
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 246.8334 - mean_absolute_error: 13.0494 - val_loss: 43.4627 - val_mean_absolute_error: 5.3982
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 197.1970 - mean_absolute_error: 11.2477 - val_loss: 34.0552 - val_mean_absolute_error: 4.9251
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 149.1565 - mean_absolute_error: 9.8289 - val_loss: 34.0597 - val_mean_absolute_error: 5.0235
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 121.3464 - mean_absolute_error: 8.5844 - val_loss: 31.1038 - val_mean_absolute_error: 4.8562
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 98.4001 - mean_absolute_error: 7.5221 - val_loss: 30.4513 - val_mean_absolute_error: 4.8560
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 79.5192 - mean_absolute_error: 6.7949 - val_loss: 39.2418 - val_mean_absolute_error: 5.1337
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 89.2978 - mean_absolute_error: 7.7491 - val_loss: 45.0583 - val_mean_absolute_error: 5.3866
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 63.6368 - mean_absolute_error: 6.2535 - val_loss: 79.7373 - val_mean_absolute_error: 7.2773
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 77.5807 - mean_absolute_error: 7.5685 - val_loss: 34.8870 - val_mean_absolute_error: 5.0169
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 63.3230 - mean_absolute_error: 6.1137 - val_loss: 33.6787 - val_mean_absolute_error: 4.9357
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 45.6509 - mean_absolute_error: 5.1934 - val_loss: 31.3715 - val_mean_absolute_error: 4.8057
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 43.6689 - mean_absolute_error: 5.1546 - val_loss: 34.7016 - val_mean_absolute_error: 4.8949
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 30.0742 - mean_absolute_error: 4.2930 - val_loss: 33.2369 - val_mean_absolute_error: 4.8086
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.6183 - mean_absolute_error: 4.7389 - val_loss: 43.1032 - val_mean_absolute_error: 5.3889
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 33.0841 - mean_absolute_error: 4.4838 - val_loss: 69.6286 - val_mean_absolute_error: 6.7352
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 31.8566 - mean_absolute_error: 4.5372 - val_loss: 69.6164 - val_mean_absolute_error: 6.7666
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 28.8048 - mean_absolute_error: 4.3287 - val_loss: 36.8554 - val_mean_absolute_error: 4.9788
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25.2278 - mean_absolute_error: 4.0346 - val_loss: 33.7490 - val_mean_absolute_error: 4.7755
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 29.4995 - mean_absolute_error: 4.2308 - val_loss: 33.2973 - val_mean_absolute_error: 4.7138
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 26.7105 - mean_absolute_error: 3.9029 - val_loss: 58.3021 - val_mean_absolute_error: 6.2326
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.9334 - mean_absolute_error: 3.7195 - val_loss: 48.0591 - val_mean_absolute_error: 5.7486
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 22.7623 - mean_absolute_error: 3.8089 - val_loss: 34.2231 - val_mean_absolute_error: 4.7531
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 28.1010 - mean_absolute_error: 4.1816 - val_loss: 51.6113 - val_mean_absolute_error: 5.9393
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.5893 - mean_absolute_error: 3.9644 - val_loss: 78.7467 - val_mean_absolute_error: 7.3141
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 29.4811 - mean_absolute_error: 4.3015 - val_loss: 69.1851 - val_mean_absolute_error: 6.8231
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.7830 - mean_absolute_error: 3.8633 - val_loss: 57.5950 - val_mean_absolute_error: 6.2375
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22.2690 - mean_absolute_error: 3.7831 - val_loss: 38.3178 - val_mean_absolute_error: 5.0588
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 20.6101 - mean_absolute_error: 3.6938 - val_loss: 45.3518 - val_mean_absolute_error: 5.5948
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 20.1830 - mean_absolute_error: 3.5112 - val_loss: 78.1703 - val_mean_absolute_error: 7.3174
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 22.2736 - mean_absolute_error: 3.7877 - val_loss: 119.1309 - val_mean_absolute_error: 9.3793
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 31.0394 - mean_absolute_error: 4.5953 - val_loss: 100.5170 - val_mean_absolute_error: 8.4452
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 24.5740 - mean_absolute_error: 4.0872 - val_loss: 50.2598 - val_mean_absolute_error: 5.8822

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])

# %% [markdown]
# Second LSTM Model

# %%
# Imports
from tensorflow import keras
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

data = pd.read_csv('/content/MicrosoftStock.csv')
print(data.head())
print(data.info())
print(data.describe())
# Out:
#     index        date   open   high    low  close    volume  Name
# 0  390198  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  390199  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  390200  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  390201  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  390202  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   1259 non-null   int64
#  1   date    1259 non-null   object
#  2   open    1259 non-null   float64
#  3   high    1259 non-null   float64
#  4   low     1259 non-null   float64
#  5   close   1259 non-null   float64
#  6   volume  1259 non-null   int64
#  7   Name    1259 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 78.8+ KB
# None
#                index         open         high          low        close  \
# count    1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   390827.000000    51.026394    51.436007    50.630397    51.063081
# std       363.586303    14.859387    14.930144    14.774630    14.852117
# min    390198.000000    27.350000    27.600000    27.230000    27.370000
# 25%    390512.500000    40.305000    40.637500    39.870000    40.310000
# 50%    390827.000000    47.440000    47.810000    47.005000    47.520000
# 75%    391141.500000    59.955000    60.435000    59.275000    59.730000
# max    391456.000000    95.140000    96.070000    93.720000    95.010000
#
#              volume
# count  1.259000e+03
# mean   3.386946e+07
# std    1.958979e+07
# min    7.425603e+06
# 25%    2.254879e+07
# 50%    2.938758e+07
# 75%    3.842024e+07
# max    2.483542e+08

# %%
# Plot 1 - Open and Close Prices of time
plt.figure(figsize=(12,6))
plt.plot(data['date'], data['open'], label="Open",color="blue")
plt.plot(data['date'], data['close'], label="Close",color="red")
plt.title("Open-Close Price over Time")
plt.legend()
# plt.show()

# Plot 2 - Trading Volume (check for outliers)
plt.figure(figsize=(12,6))
plt.plot(data['date'],data['volume'],label="Volume",color="orange")
plt.title("Stock Volume over Time")
# plt.show()


# Drop non-numeric columns
numeric_data = data.select_dtypes(include=["int64","float64"])

# Plot 3 - Check for correlation between features
plt.figure(figsize=(8,6))
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
# plt.show()
# Out:
# Text(0.5, 1.0, 'Feature Correlation Heatmap')

# %%
#Convert the Data into Date time then create a date filter
data['date'] = pd.to_datetime(data['date'])

prediction = data.loc[
    (data['date'] > datetime(2013,1,1)) &
    (data['date'] < datetime(2018,1,1))
]

plt.figure(figsize=(12,6))
plt.plot(data['date'], data['close'],color="blue")
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Price over time")
# Out:
# Text(0.5, 1.0, 'Price over time')

# %%
# Prepare for the LSTM Model (Sequential)
stock_close = data.filter(["close"])
dataset = stock_close.values #convert to numpy array
training_data_len = int(np.ceil(len(dataset) * 0.95))

# Preprocessing Stages
scaler = StandardScaler()
scaled_data = scaler.fit_transform(dataset)

training_data = scaled_data[:training_data_len] #95% of all out data

X_train, y_train = [], []


# Create a sliding window for our stock (60 days)
for i in range(60, len(training_data)):
    X_train.append(training_data[i-60:i, 0])
    y_train.append(training_data[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Build the Model
model = keras.models.Sequential()

# First Layer
model.add(keras.layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1],1)))

# Second Layer
model.add(keras.layers.LSTM(64, return_sequences=False))

# 3rd Layer (Dense)
model.add(keras.layers.Dense(128, activation="relu"))

# 4th Layer (Dropout)
model.add(keras.layers.Dropout(0.5))

# Final Output Layer
model.add(keras.layers.Dense(1))

model.summary()
model.compile(optimizer="adam",
              loss="mae",
              metrics=[keras.metrics.RootMeanSquaredError()])


training = model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,369 (228.00 KB)
#  Trainable params: 58,369 (228.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.3986 - root_mean_squared_error: 0.5527
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.1358 - root_mean_squared_error: 0.1817
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.1297 - root_mean_squared_error: 0.1721
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.1142 - root_mean_squared_error: 0.1595
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.1124 - root_mean_squared_error: 0.1543
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.1142 - root_mean_squared_error: 0.1626
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.1037 - root_mean_squared_error: 0.1413
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.1042 - root_mean_squared_error: 0.1414
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.1030 - root_mean_squared_error: 0.1388
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.1023 - root_mean_squared_error: 0.1414
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.1002 - root_mean_squared_error: 0.1368
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0987 - root_mean_squared_error: 0.1326
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0969 - root_mean_squared_error: 0.1364
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0993 - root_mean_squared_error: 0.1344
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0908 - root_mean_squared_error: 0.1245
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0992 - root_mean_squared_error: 0.1369
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0963 - root_mean_squared_error: 0.1386
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0972 - root_mean_squared_error: 0.1347
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0955 - root_mean_squared_error: 0.1300
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0943 - root_mean_squared_error: 0.1283

# %%
# Prep the test data
test_data = scaled_data[training_data_len - 60:]
X_test, y_test = [], dataset[training_data_len:]


for i in range(60, len(test_data)):
    X_test.append(test_data[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1 ))

# %%
# Make a Prediction
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 480ms/step

# %%
# Plotting data
train = data[:training_data_len]
test =  data[training_data_len:]

test = test.copy()

test['Predictions'] = predictions

plt.figure(figsize=(12,8))
plt.plot(train['date'], train['close'], label="Train (Actual)", color='blue')
plt.plot(test['date'], test['close'], label="Test (Actual)", color='orange')
plt.plot(test['date'], test['Predictions'], label="Predictions", color='red')
plt.title("Our Stock Predictions")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.show()
